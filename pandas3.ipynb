# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudhanshugupta26/pandas_code/blob/main/pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df =sns.load_dataset("mpg")

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %%
df["origin"].unique(
)
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black")

plt.show()

# %%
plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black")
plt.xlabel('DISPLACEMENT')
plt.ylabel('horsepower')
plt.show()

# %%
plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black")
plt.title('scatterplot for displacement vs horsepower')
# Out:
# Text(0.5, 1.0, 'scatterplot for displacement vs horsepower')

# %%
plt.figure(figsize=(9,8))
plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black")

# %%
plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black")
plt.grid(

)

# %%
plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black")
plt.xlabel('DISPLACEMENT')
plt.ylabel('horsepower')
plt.legend(loc="lower left")

# %%
plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black",s=220)

# %%
#bubble chart : it contains 3 variables
plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black",s="cylinders")

# %%
plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black",z="cylinders")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-bbe63d45d31f> in <cell line: 1>()
# ----> 1 plt.scatter(data= df , x= 'displacement', y='horsepower',c='red',marker="*",edgecolors="black",z="cylinders")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
df[["origin","horsepower","name"]]
# Out:
#      origin  horsepower                       name
# 0       usa       130.0  chevrolet chevelle malibu
# 1       usa       165.0          buick skylark 320
# 2       usa       150.0         plymouth satellite
# 3       usa       150.0              amc rebel sst
# 4       usa       140.0                ford torino
# ..      ...         ...                        ...
# 393     usa        86.0            ford mustang gl
# 394  europe        52.0                  vw pickup
# 395     usa        84.0              dodge rampage
# 396     usa        79.0                ford ranger
# 397     usa        82.0                 chevy s-10
#
# [398 rows x 3 columns]

# %%
df.groupby(by="origin")[["horsepower","name"]].max()
# Out:
#         horsepower                         name
# origin
# europe       133.0             vw rabbit custom
# japan        132.0  toyouta corona mark ii (sw)
# usa          230.0           pontiac ventura sj

# %%
df.groupby(by="origin")[["weight"]].count()
# Out:
#         weight
# origin
# europe      70
# japan       79
# usa        249

# %%
df.groupby(by='origin')[['weight']].min()
# Out:
#         weight
# origin
# europe    1825
# japan     1613
# usa       1800

# %%
df.groupby(by="cylinders")[["horsepower"]].sum()
# Out:
#            horsepower
# cylinders
# 3               397.0
# 4             15578.0
# 5               247.0
# 6              8425.0
# 8             16305.0

# %%
df.groupby(["origin","cylinders"]).sum()
# Out:
# <ipython-input-44-80b4e5b85068>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["origin","cylinders"]).sum()
#                      mpg  displacement  horsepower  weight  acceleration  \
# origin cylinders
# europe 4          1789.9        6566.0      4777.0  146791        1053.5
#        5            82.1         435.0       247.0    9310          55.9
#        6            80.4         639.0       454.0   13530          65.7
# japan  3            82.2         290.0       397.0    9594          53.0
#        4          2180.1        6884.0      5215.0  148591        1143.3
#        6           143.3         940.0       695.0   17292          81.3
# usa    4          2004.5        8948.5      5586.0  175476        1189.9
# ...

# %%
df.groupby(["origin","cylinders"]).count()
# Out:
#                   mpg  displacement  horsepower  weight  acceleration  \
# origin cylinders
# europe 4           63            63          61      63            63
#        5            3             3           3       3             3
#        6            4             4           4       4             4
# japan  3            4             4           4       4             4
#        4           69            69          69      69            69
#        6            6             6           6       6             6
# usa    4           72            72          69      72            72
#        6           74            74          73      74            74
#        8          103           103         103     103           103
#
#                   model_year  name
# origin cylinders
# europe 4                  63    63
#        5                   3     3
#        6                   4     4
# japan  3                   4     4
#        4                  69    69
# ...

# %%
plt.bar(data=df,x="origin",height="cylinders")
# Out:
# <BarContainer object of 398 artists>

# %%
df.groupby(["origin"])[["cylinders"]].max()
# Out:
#         cylinders
# origin
# europe          6
# japan           6
# usa             8

# %%
plt.bar(data=df,x="origin",height="cylinders",width=0.3,color="red")
# Out:
# <BarContainer object of 398 artists>
