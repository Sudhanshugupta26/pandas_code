# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudhanshugupta26/pandas_code/blob/main/pandas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv("final_data.csv",index_col=0)

# %%
df
# Out:
#                                                 address  \
# 0     Sheetal Vihar, Bhagwant Nagar, Dr.Homi Bhabha ...
# 1               Samraat Dream Citi, Samta Nagar, Nashik
# 2            Suryaprakash Apartment,Nashik Road, Nashik
# 3                Adishvar Residency,Nashik Road, Nashik
# 4                                   Nashik Road, Nashik
# ...                                                 ...
# 5491              Prashant Nagar, Pathardi Phata,Nashik
# 5492                     Vasantdadanagar, Adgaon,Nashik
# 5493                  Samarth Nagar, Makhmalabad,Nashik
# 5494                             Bhor Town Ship, Nashik
# 5495                                   Chandshi, Nashik
#
#                                      owners          housetype  \
# 0                           Mahendra Kotwal          Apartment
# 1                            Jiten Dadarkar          Apartment
# 2                                    Pankaj          Apartment
# 3                                    Saurav          Apartment
# 4                          Vivek Pavanaskar          Apartment
# ...                                     ...                ...
# 5491                             Datta Kale  Independent house
# 5492                         Geeta Buildcon  Independent house
# 5493  Atharvashree Buildmat Private Limited  Independent house
# 5494               Shree Prakash Developers  Independent house
# 5495                           Nirman Group  Independent house
#
#      house_condition  BHK  price  per_month_emi  total_sqft  \
# 0                old  3.0  75.00          39.72      1550.0
# 1                old  2.0  41.00          21.71      1000.0
# 2                old  2.0  53.35          28.25       970.0
# 3                old  2.0  55.00          29.13      1000.0
# 4                old  2.0  27.00          14.30       853.0
# ...              ...  ...    ...            ...         ...
# 5491             old  4.0  92.25          45.80         NaN
# 5492             old  2.0    NaN            NaN         NaN
# 5493             old  2.0  34.32          18.17         NaN
# 5494             old  NaN    NaN            NaN         NaN
# 5495             old  NaN    NaN            NaN         NaN
#
#                                              cordinates   latitude  longitude
# 0                                         Sheetal Vihar  19.987960  73.787390
# 1                                    Samraat Dream Citi  19.982460  73.811840
# 2                                         Surya Prakash  19.975850  73.788750
# 3     Nashik Road, Vadner Dumala, Nashik, Maharashtr...  19.930532  73.811734
# 4                      Nashik Road, Nashik, Maharashtra  19.955310  73.840890
# ...                                                 ...        ...        ...
# 5491  Prashant Nagar, Pathardi Phata, Nashik, Mahara...  19.951040  73.756990
# 5492      Vasantdada Nagar, Adgaon, Nashik, Maharashtra  20.031780  73.855100
# 5493   Samarth Nagar, Makhamalabad, Nashik, Maharashtra  20.049050  73.796960
# 5494  Town Ship Colony, Panchavati, Nashik, Maharashtra  20.027090  73.821100
# 5495  Chandshi, Nashik Sub-District, Nashik, Maharas...  20.038750  73.750250
#
# [5496 rows x 11 columns]

# %%
sns.boxplot(data =df,x="total_sqft")
# Out:
# <Axes: xlabel='total_sqft'>

# %%
px.box(df,x="total_sqft",height=300)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="aa359e7b-adb0-4ea1-91d5-4d6b6deac3b3" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa359e7b-adb0-4ea1-91d5-4d6b6deac3b3")) {                    Plotly.newPlot(                        "aa359e7b-adb0-4ea1-91d5-4d6b6deac3b3",                        [{"alignmentgroup":"True","hovertemplate":"total_sqft=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[1550.0,1000.0,970.0,1000.0,853.0,1050.0,1035.0,1375.0,850.0,1020.0,810.0,810.0,1250.0,1900.0,840.0,1100.0,713.0,950.0,990.0,560.0,1050.0,720.0,845.0,853.0,900.0,1250.0,850.0,850.0,850.0,1395.0,1100.0,1000.0,610.0,741.0,1100.0,610.0,835.0,1035.0,1600.0,984.0,1035.0,750.0,900.0,775.0,1200.0,750.0,1050.0,1500.0,700.0,786.0,733.0,775.0,960.0,1050.0,1050.0,1085.0,500.0,850.0,615.0,800.0,756.0,990.0,912.0,850.0,735.0,750.0,800.0,912.0,1290.0,1290.0,850.0,850.0,720.0,650.0,900.0,2576.0,860.0,500.0,670.0,2470.0,980.0,750.0,600.0,420.0,950.0,660.0,650.0,650.0,630.0,1190.0,1040.0,672.0,905.0,955.0,895.0,800.0,1060.0,751