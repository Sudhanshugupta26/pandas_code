# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudhanshugupta26/pandas_code/blob/main/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset("titanic")

# %%
df.corr()
# Out:
# <ipython-input-2-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-4-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
sns.histplot(df,x="fare")
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(df,x="age")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df,x="fare",bins=20)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
df1=df.copy()

# %%
df2 = df1.sort_values(by="age")

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 859         0       3    male   NaN      0      0   7.2292        C   Third
# 863         0       3  female   NaN      8      2  69.5500        S   Third
# 868         0       3    male   NaN      0      0   9.5000        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.reset_index(drop=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           1       3    male  0.42      0      1   8.5167        C   Third
# 1           1       2    male  0.67      1      1  14.5000        S  Second
# 2           1       3  female  0.75      2      1  19.2583        C   Third
# 3           1       3  female  0.75      2      1  19.2583        C   Third
# 4           1       2    male  0.83      0      2  29.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       3    male   NaN      0      0   7.2292        C   Third
# 887         0       3  female   NaN      8      2  69.5500        S   Third
# 888         0       3    male   NaN      0      0   9.5000        S   Third
# 889         0       3    male   NaN      0      0   7.8958        S   Third
# 890         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.set_index("age")
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked   class    who  \
# age
# 0.42         1       3    male      0      1   8.5167        C   Third  child
# 0.67         1       2    male      1      1  14.5000        S  Second  child
# 0.75         1       3  female      2      1  19.2583        C   Third  child
# 0.75         1       3  female      2      1  19.2583        C   Third  child
# 0.83         1       2    male      0      2  29.0000        S  Second  child
# ...        ...     ...     ...    ...    ...      ...      ...     ...    ...
# NaN          0       3    male      0      0   7.2292        C   Third    man
# NaN          0       3  female      8      2  69.5500        S   Third  woman
# NaN          0       3    male      0      0   9.5000        S   Third    man
# NaN          0       3    male      0      0   7.8958        S   Third    man
# NaN          0       3  female      1      2  23.4500        S   Third  woman
#
# ...

# %%
df2.set_index(["age","fare"])
# Out:
#               survived  pclass     sex  sibsp  parch embarked   class    who  \
# age  fare
# 0.42 8.5167          1       3    male      0      1        C   Third  child
# 0.67 14.5000         1       2    male      1      1        S  Second  child
# 0.75 19.2583         1       3  female      2      1        C   Third  child
#      19.2583         1       3  female      2      1        C   Third  child
# 0.83 29.0000         1       2    male      0      2        S  Second  child
# ...                ...     ...     ...    ...    ...      ...     ...    ...
# NaN  7.2292          0       3    male      0      0        C   Third    man
#      69.5500         0       3  female      8      2        S   Third  woman
#      9.5000          0       3    male      0      0        S   Third    man
#      7.8958          0       3    male      0      0        S   Third    man
#      23.4500         0       3  female      1      2        S   Third  woman
#
# ...
